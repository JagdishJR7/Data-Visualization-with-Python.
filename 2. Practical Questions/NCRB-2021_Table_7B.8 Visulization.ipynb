# %% [markdown]
# # NCRB-2021_Table_7B.8 visulization

# %%
import pandas as pd

# %%
data = pd.read_csv("NCRB-2021_Table_7B.8.csv")
data.head()
# Out:
#   Sl. No.                     City  Persons Arrested - Male  \
# 0       1      Ahmedabad (Gujarat)                      382
# 1       2    Bengaluru (Karnataka)                      270
# 2       3     Chennai (Tamil Nadu)                       20
# 3       4  Coimbatore (Tamil Nadu)                       18
# 4       5               Delhi City                      186
#
#    Persons Arrested - Female  Persons Arrested - Transgender  \
# 0                         40                               0
# 1                         52                               0
# 2                          1                               0
# 3                          0                               0
# 4                         13                               0
#
#    Persons Arrested - Total  Persons Charge sheeted - Male  \
# 0                       422                            382
# 1                       322                            251
# ...

# %%
data.tail()
# Out:
#          Sl. No.                  City  Persons Arrested - Male  \
# 15            16  Nagpur (Maharashtra)                      120
# 16            17         Patna (Bihar)                       57
# 17            18    Pune (Maharashtra)                       79
# 18            19       Surat (Gujarat)                       32
# 19  Total Cities          Total Cities                     2101
#
#     Persons Arrested - Female  Persons Arrested - Transgender  \
# 15                          3                               0
# 16                          0                               0
# 17                          2                               0
# 18                          0                               0
# 19                        131                               0
#
#     Persons Arrested - Total  Persons Charge sheeted - Male  \
# 15                       123                            120
# 16                        57                             48
# ...

# %%
data.columns
# Out:
# Index(['Sl. No.', 'City', 'Persons Arrested - Male',
#        'Persons Arrested - Female', 'Persons Arrested - Transgender',
#        'Persons Arrested - Total', 'Persons Charge sheeted - Male',
#        'Persons Charge sheeted - Female',
#        'Persons Charge sheeted - Transgender',
#        'Persons Charge sheeted - Total', 'Persons Convicted - Male',
#        'Persons Convicted - Female', 'Persons Convicted - Transgender',
#        'Persons Convicted - Total', 'Persons Discharged - Male',
#        'Persons Discharged - Female', 'Persons Discharged - Transgender',
#        'Persons Discharged - Total', 'Persons Acquitted - Male',
#        'Persons Acquitted - Female', 'Persons Acquitted - Transgender',
#        'Persons Acquitted - Total'],
#       dtype='object')

# %%
data.shape
# Out:
# (20, 22)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of          Sl. No.                       City  Persons Arrested - Male  \
# 0              1        Ahmedabad (Gujarat)                      382
# 1              2      Bengaluru (Karnataka)                      270
# 2              3       Chennai (Tamil Nadu)                       20
# 3              4    Coimbatore (Tamil Nadu)                       18
# 4              5                 Delhi City                      186
# 5              6  Ghaziabad (Uttar Pradesh)                       44
# 6              7      Hyderabad (Telangana)                       65
# 7              8    Indore (Madhya Pradesh)                       65
# 8              9         Jaipur (Rajasthan)                      178
# 9             10     Kanpur (Uttar Pradesh)                      387
# 10            11             Kochi (Kerala)                       15
# 11            12      Kolkata (West Bengal)                        2
# ...

# %% [markdown]
# # Importing matplotlib and seaborn library :

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data.hist(figsize=(20,20))
plt.show()

# %%
data.head(2)
# Out:
#   Sl. No.                   City  Persons Arrested - Male  \
# 0       1    Ahmedabad (Gujarat)                      382
# 1       2  Bengaluru (Karnataka)                      270
#
#    Persons Arrested - Female  Persons Arrested - Transgender  \
# 0                         40                               0
# 1                         52                               0
#
#    Persons Arrested - Total  Persons Charge sheeted - Male  \
# 0                       422                            382
# 1                       322                            251
#
#    Persons Charge sheeted - Female  Persons Charge sheeted - Transgender  \
# 0                               39                                     0
# 1                               42                                     0
#
#    Persons Charge sheeted - Total  ...  Persons Convicted - Transgender  \
# 0                             421  ...                                0
# ...
