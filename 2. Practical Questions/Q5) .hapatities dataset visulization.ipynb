# %% [markdown]
# ## HepatitisCdata visulization

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("HepatitisCdata.csv")
data.head()
# Out:
#    Unnamed: 0       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  \
# 0           1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93
# 1           2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17
# 2           3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84
# 3           4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33
# 4           5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15
#
#    CHOL   CREA   GGT  PROT
# 0  3.23  106.0  12.1  69.0
# 1  4.80   74.0  15.6  76.5
# 2  5.20   86.0  33.2  79.3
# 3  4.74   80.0  33.8  75.7
# 4  4.32   76.0  29.9  68.7

# %%
data = data.rename(columns={"Unnamed: 0":"Sno."})
data.head(2)
# Out:
#    Sno.       Category  Age Sex   ALB   ALP   ALT   AST  BIL    CHE  CHOL  \
# 0     1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1  7.5   6.93  3.23
# 1     2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7  3.9  11.17  4.80
#
#     CREA   GGT  PROT
# 0  106.0  12.1  69.0
# 1   74.0  15.6  76.5

# %%
data.tail()
# Out:
#      Sno.     Category  Age Sex   ALB    ALP    ALT    AST   BIL   CHE  CHOL  \
# 610   611  3=Cirrhosis   62   f  32.0  416.6    5.9  110.3  50.0  5.57  6.30
# 611   612  3=Cirrhosis   64   f  24.0  102.8    2.9   44.4  20.0  1.54  3.02
# 612   613  3=Cirrhosis   64   f  29.0   87.3    3.5   99.0  48.0  1.66  3.63
# 613   614  3=Cirrhosis   46   f  33.0    NaN   39.0   62.0  20.0  3.56  4.20
# 614   615  3=Cirrhosis   59   f  36.0    NaN  100.0   80.0  12.0  9.07  5.30
#
#      CREA    GGT  PROT
# 610  55.7  650.9  68.5
# 611  63.0   35.9  71.3
# 612  66.7   64.2  82.0
# 613  52.0   50.0  71.0
# 614  67.0   34.0  68.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 615 entries, 0 to 614
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sno.      615 non-null    int64
#  1   Category  615 non-null    object
#  2   Age       615 non-null    int64
#  3   Sex       615 non-null    object
#  4   ALB       614 non-null    float64
#  5   ALP       597 non-null    float64
#  6   ALT       614 non-null    float64
#  7   AST       615 non-null    float64
#  8   BIL       615 non-null    float64
#  9   CHE       615 non-null    float64
#  10  CHOL      605 non-null    float64
#  11  CREA      615 non-null    float64
#  12  GGT       615 non-null    float64
#  13  PROT      614 non-null    float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 67.4+ KB

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.apply(pd.Series.first_valid_index, axis=1)
# Out:
# 0      Sno.
# 1      Sno.
# 2      Sno.
# 3      Sno.
# 4      Sno.
#        ...
# 610    Sno.
# 611    Sno.
# 612    Sno.
# 613    Sno.
# 614    Sno.
# Length: 615, dtype: object

# %% [markdown]
# ### To find the no. null values in the dataset

# %%
data.isnull().values.sum()
# Out:
# 31

# %%
data.describe()
# Out:
#              Sno.         Age         ALB         ALP         ALT         AST  \
# count  615.000000  615.000000  614.000000  597.000000  614.000000  615.000000
# mean   308.000000   47.408130   41.620195   68.283920   28.450814   34.786341
# std    177.679487   10.055105    5.780629   26.028315   25.469689   33.090690
# min      1.000000   19.000000   14.900000   11.300000    0.900000   10.600000
# 25%    154.500000   39.000000   38.800000   52.500000   16.400000   21.600000
# 50%    308.000000   47.000000   41.950000   66.200000   23.000000   25.900000
# 75%    461.500000   54.000000   45.200000   80.100000   33.075000   32.900000
# max    615.000000   77.000000   82.200000  416.600000  325.300000  324.000000
#
#               BIL         CHE        CHOL         CREA         GGT        PROT
# count  615.000000  615.000000  605.000000   615.000000  615.000000  614.000000
# mean    11.396748    8.196634    5.368099    81.287805   39.533171   72.044137
# ...

# %%
data.head(1)
# Out:
#    Sno.       Category  Age Sex   ALB   ALP  ALT   AST  BIL   CHE  CHOL  \
# 0     1  0=Blood Donor   32   m  38.5  52.5  7.7  22.1  7.5  6.93  3.23
#
#     CREA   GGT  PROT
# 0  106.0  12.1  69.0

# %%
data['name'] = data['Category'].str.split(',',expand=False)
data.head()
# Out:
#    Sno.       Category  Age Sex   ALB   ALP   ALT   AST   BIL    CHE  CHOL  \
# 0     1  0=Blood Donor   32   m  38.5  52.5   7.7  22.1   7.5   6.93  3.23
# 1     2  0=Blood Donor   32   m  38.5  70.3  18.0  24.7   3.9  11.17  4.80
# 2     3  0=Blood Donor   32   m  46.9  74.7  36.2  52.6   6.1   8.84  5.20
# 3     4  0=Blood Donor   32   m  43.2  52.0  30.6  22.6  18.9   7.33  4.74
# 4     5  0=Blood Donor   32   m  39.2  74.1  32.6  24.8   9.6   9.15  4.32
#
#     CREA   GGT  PROT             name
# 0  106.0  12.1  69.0  [0=Blood Donor]
# 1   74.0  15.6  76.5  [0=Blood Donor]
# 2   86.0  33.2  79.3  [0=Blood Donor]
# 3   80.0  33.8  75.7  [0=Blood Donor]
# 4   76.0  29.9  68.7  [0=Blood Donor]
